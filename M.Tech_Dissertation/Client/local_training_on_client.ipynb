# %%
import os
import json
import time
import base64
import pathlib
from typing import Dict, List, Optional, Tuple

import requests
import numpy as np
import pandas as pd
import tensorflow as tf

# %%
# --------------------- CONFIG ---------------------
OWNER = "Triss11"
REPO  = "FL"
REF   = "main"
GLOBAL_MODEL_DIR = "M.Tech_Dissertation/Server/global_model"

# %%
# Local data roots
FNN_USERS_DIR  = pathlib.Path("/Users/sohinikar/FL/M.Tech_Dissertation/Client/data/FNN_BC_test_data")
LSTM_USERS_DIR = pathlib.Path("/Users/sohinikar/FL/M.Tech_Dissertation/Client/data/LSTM_BC_test_data")

# Output (weights + params)
FNN_OUT_ROOT  = pathlib.Path("/Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC")
LSTM_OUT_ROOT = pathlib.Path("/Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC")

# %%
# Training hyperparams (adjust as you like)
EPOCHS = 5
BATCH_SIZE = 64
OPTIMIZER = "adam"
LOSS_FNN  = "binary_crossentropy"   # change to categorical_crossentropy if multiclass
LOSS_LSTM = "binary_crossentropy"
METRICS   = ["accuracy"]

# File naming conventions for model selection (we’ll try to guess)
FNN_HINTS  = ("fnn", "dense", "ffn", "mlp", "FNN", "Dense", "FFN", "MLP")
LSTM_HINTS = ("lstm", "rnn", "LSTM", "RNN")

# %%
def gh_session() -> requests.Session:
    s = requests.Session()
    token = os.environ.get("GITHUB_TOKEN")
    if token:
        s.headers.update({"Authorization": f"Bearer {token}"})
    s.headers.update({"Accept": "application/vnd.github+json"})
    return s

# %%
def list_github_dir(session: requests.Session, owner: str, repo: str, path: str, ref: str="main") -> List[Dict]:
    url = f"https://api.github.com/repos/{owner}/{repo}/contents/{path}?ref={ref}"
    r = session.get(url)
    if r.status_code != 200:
        raise RuntimeError(f"GitHub list failed: {r.status_code} {r.text}")
    return r.json()

# %%
def choose_model_files(entries: List[Dict]) -> Tuple[Optional[Dict], Optional[Dict]]:
    """
    Pick one FNN-like and one LSTM-like file from a list of contents entries.
    Preference: filenames containing hints. Fallback: first .keras/.h5 found.
    """
    model_files = [e for e in entries if e.get("type") == "file" and any(e["name"].endswith(ext) for ext in (".keras", ".h5"))]

    def pick_with_hints(hints):
        for e in model_files:
            name = e["name"]
            if any(h in name for h in hints):
                return e
        return None

    fnn = pick_with_hints(FNN_HINTS)
    lstm = pick_with_hints(LSTM_HINTS)

    # Fallbacks if not found via hints
    if fnn is None and model_files:
        fnn = model_files[0]
    if lstm is None and len(model_files) > 1:
        # pick something different than fnn if possible
        for e in model_files:
            if e is not fnn:
                lstm = e
                break
    elif lstm is None and model_files:
        lstm = model_files[0]

    return fnn, lstm

def download_file(session: requests.Session, entry: Dict, dest: pathlib.Path) -> pathlib.Path:
    """
    Download a file using 'download_url' from the GitHub contents API.
    """
    url = entry.get("download_url")
    if not url:
        raise RuntimeError(f"No download_url for {entry.get('name')}")
    dest.parent.mkdir(parents=True, exist_ok=True)
    r = session.get(url, stream=True)
    if r.status_code != 200:
        raise RuntimeError(f"Download failed for {entry.get('name')}: {r.status_code} {r.text}")
    with open(dest, "wb") as f:
        for chunk in r.iter_content(chunk_size=1024 * 1024):
            if chunk:
                f.write(chunk)
    return dest

def load_user_dirs(root: pathlib.Path) -> List[pathlib.Path]:
    """
    Return sorted list of user_* directories that contain X.csv and y.csv.
    """
    if not root.exists():
        return []
    users = []
    for p in sorted(root.glob("user_*")):
        if (p / "X.csv").exists() and (p / "y.csv").exists():
            users.append(p)
    return users

def train_one_user(model_path: pathlib.Path, user_dir: pathlib.Path, out_dir: pathlib.Path,
                   is_lstm: bool, loss: str) -> Dict:
    """
    Load model, train on user data, save weights + params.json to out_dir.
    """
    # Load data
    X = pd.read_csv(user_dir / "X.csv").to_numpy(dtype=np.float32)
    y = pd.read_csv(user_dir / "y.csv")["label"].to_numpy().astype(np.float32).reshape(-1)

    if is_lstm:
        # reshape to (N, 1, D)
        X = X.reshape((X.shape[0], 1, X.shape[1])).astype(np.float32)

    # Load model
    model = tf.keras.models.load_model(str(model_path))

    # Compile fresh (weights may not include optimizer state)
    model.compile(optimizer=OPTIMIZER, loss=loss, metrics=METRICS)

    # Train (no validation, as requested)
    start = time.time()
    hist = model.fit(X, y, epochs=EPOCHS, batch_size=BATCH_SIZE, verbose=0)
    elapsed = time.time() - start

    # Prepare output
    out_dir.mkdir(parents=True, exist_ok=True)
    weights_path = out_dir / f"{user_dir.name}.weights.h5"
    model.save_weights(str(weights_path))

    # Capture final metrics from history
    final_metrics = {}
    for k, v in hist.history.items():
        final_metrics[f"final_{k}"] = float(v[-1])

    params = {
        "user": user_dir.name,
        "model_file": model_path.name,
        "samples": int(X.shape[0]),
        "features": int(X.shape[-1]),
        "is_lstm": is_lstm,
        "epochs": EPOCHS,
        "batch_size": BATCH_SIZE,
        "optimizer": OPTIMIZER,
        "loss": loss,
        "metrics": METRICS,
        "train_seconds": round(elapsed, 3),
        **final_metrics
    }
    with open(out_dir / "params.json", "w") as f:
        json.dump(params, f, indent=2)

    return {"weights": str(weights_path), "params": params}

def main():
    session = gh_session()

    # 1) List models in the global_model folder
    print("🔎 Listing global model directory on GitHub…")
    entries = list_github_dir(session, OWNER, REPO, GLOBAL_MODEL_DIR, REF)

    # 2) Choose FNN and LSTM model files
    fnn_entry, lstm_entry = choose_model_files(entries)
    if not fnn_entry or not lstm_entry:
        raise RuntimeError("Could not locate suitable .keras/.h5 model files in the global_model folder.")

    # 3) Download models locally (cache under ./_downloaded_models)
    cache_dir = pathlib.Path("./_downloaded_models")
    fnn_local  = download_file(session, fnn_entry,  cache_dir / fnn_entry["name"])
    lstm_local = download_file(session, lstm_entry, cache_dir / lstm_entry["name"])
    print(f"⬇️  Downloaded FNN model:  {fnn_local}")
    print(f"⬇️  Downloaded LSTM model: {lstm_local}")

    # 4) Enumerate users
    fnn_users  = load_user_dirs(FNN_USERS_DIR)
    lstm_users = load_user_dirs(LSTM_USERS_DIR)

    if not fnn_users:
        print(f"⚠️  No valid FNN user folders found under: {FNN_USERS_DIR}")
    if not lstm_users:
        print(f"⚠️  No valid LSTM user folders found under: {LSTM_USERS_DIR}")

    # 5) Train FNN users
    print(f"🏃 Training FNN users ({len(fnn_users)}) …")
    for udir in fnn_users:
        out_dir = FNN_OUT_ROOT / udir.name
        try:
            result = train_one_user(fnn_local, udir, out_dir, is_lstm=False, loss=LOSS_FNN)
            print(f"✅ {udir.name}: saved -> {result['weights']}")
        except Exception as e:
            print(f"❌ {udir.name}: {e}")

    # 6) Train LSTM users
    print(f"🏃 Training LSTM users ({len(lstm_users)}) …")
    for udir in lstm_users:
        out_dir = LSTM_OUT_ROOT / udir.name
        try:
            result = train_one_user(lstm_local, udir, out_dir, is_lstm=True, loss=LOSS_LSTM)
            print(f"✅ {udir.name}: saved -> {result['weights']}")
        except Exception as e:
            print(f"❌ {udir.name}: {e}")

    print("🎉 Done.")

if __name__ == "__main__":
    main()
# Out:
# 🔎 Listing global model directory on GitHub…
# ⬇️  Downloaded FNN model:  _downloaded_models/global_FNN_model.keras
# ⬇️  Downloaded LSTM model: _downloaded_models/global_lstm_model.keras
# 🏃 Training FNN users (128) …
# ✅ user_001: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_001/user_001.weights.h5
# ✅ user_002: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_002/user_002.weights.h5
# ✅ user_003: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_003/user_003.weights.h5
# ✅ user_004: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_004/user_004.weights.h5
# ✅ user_005: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_005/user_005.weights.h5
# ✅ user_006: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_006/user_006.weights.h5
# ✅ user_007: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_007/user_007.weights.h5
# ✅ user_008: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_008/user_008.weights.h5
# ✅ user_009: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_009/user_009.weights.h5
# ✅ user_010: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_010/user_010.weights.h5
# ✅ user_011: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_011/user_011.weights.h5
# ✅ user_012: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_012/user_012.weights.h5
# ✅ user_013: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_013/user_013.weights.h5
# ✅ user_014: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_014/user_014.weights.h5
# ✅ user_015: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_015/user_015.weights.h5
# ✅ user_016: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_016/user_016.weights.h5
# ✅ user_017: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_017/user_017.weights.h5
# ✅ user_018: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_018/user_018.weights.h5
# ✅ user_019: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_019/user_019.weights.h5
# ✅ user_020: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_020/user_020.weights.h5
# ✅ user_021: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_021/user_021.weights.h5
# ✅ user_022: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_022/user_022.weights.h5
# ✅ user_023: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_023/user_023.weights.h5
# ✅ user_024: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_024/user_024.weights.h5
# ✅ user_025: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_025/user_025.weights.h5
# ✅ user_026: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_026/user_026.weights.h5
# ✅ user_027: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_027/user_027.weights.h5
# ✅ user_028: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_028/user_028.weights.h5
# ✅ user_029: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_029/user_029.weights.h5
# ✅ user_030: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_030/user_030.weights.h5
# ✅ user_031: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_031/user_031.weights.h5
# ✅ user_032: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_032/user_032.weights.h5
# ✅ user_033: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_033/user_033.weights.h5
# ✅ user_034: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_034/user_034.weights.h5
# ✅ user_035: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_035/user_035.weights.h5
# ✅ user_036: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_036/user_036.weights.h5
# ✅ user_037: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_037/user_037.weights.h5
# ✅ user_038: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_038/user_038.weights.h5
# ✅ user_039: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_039/user_039.weights.h5
# ✅ user_040: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_040/user_040.weights.h5
# ✅ user_041: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_041/user_041.weights.h5
# ✅ user_042: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_042/user_042.weights.h5
# ✅ user_043: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_043/user_043.weights.h5
# ✅ user_044: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_044/user_044.weights.h5
# ✅ user_045: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_045/user_045.weights.h5
# ✅ user_046: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_046/user_046.weights.h5
# ✅ user_047: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_047/user_047.weights.h5
# ✅ user_048: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_048/user_048.weights.h5
# ✅ user_049: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_049/user_049.weights.h5
# ✅ user_050: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_050/user_050.weights.h5
# ✅ user_051: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_051/user_051.weights.h5
# ✅ user_052: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_052/user_052.weights.h5
# ✅ user_053: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_053/user_053.weights.h5
# ✅ user_054: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_054/user_054.weights.h5
# ✅ user_055: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_055/user_055.weights.h5
# ✅ user_056: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_056/user_056.weights.h5
# ✅ user_057: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_057/user_057.weights.h5
# ✅ user_058: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_058/user_058.weights.h5
# ✅ user_059: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_059/user_059.weights.h5
# ✅ user_060: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_060/user_060.weights.h5
# ✅ user_061: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_061/user_061.weights.h5
# ✅ user_062: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_062/user_062.weights.h5
# ✅ user_063: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_063/user_063.weights.h5
# ✅ user_064: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_064/user_064.weights.h5
# ✅ user_065: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_065/user_065.weights.h5
# ✅ user_066: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_066/user_066.weights.h5
# ✅ user_067: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_067/user_067.weights.h5
# ✅ user_068: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_068/user_068.weights.h5
# ✅ user_069: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_069/user_069.weights.h5
# ✅ user_070: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_070/user_070.weights.h5
# ✅ user_071: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_071/user_071.weights.h5
# ✅ user_072: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_072/user_072.weights.h5
# ✅ user_073: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_073/user_073.weights.h5
# ✅ user_074: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_074/user_074.weights.h5
# ✅ user_075: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_075/user_075.weights.h5
# ✅ user_076: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_076/user_076.weights.h5
# ✅ user_077: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_077/user_077.weights.h5
# ✅ user_078: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_078/user_078.weights.h5
# ✅ user_079: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_079/user_079.weights.h5
# ✅ user_080: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_080/user_080.weights.h5
# ✅ user_081: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_081/user_081.weights.h5
# ✅ user_082: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_082/user_082.weights.h5
# ✅ user_083: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_083/user_083.weights.h5
# ✅ user_084: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_084/user_084.weights.h5
# ✅ user_085: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_085/user_085.weights.h5
# ✅ user_086: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_086/user_086.weights.h5
# ✅ user_087: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_087/user_087.weights.h5
# ✅ user_088: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_088/user_088.weights.h5
# ✅ user_089: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_089/user_089.weights.h5
# ✅ user_090: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_090/user_090.weights.h5
# ✅ user_091: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_091/user_091.weights.h5
# ✅ user_092: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_092/user_092.weights.h5
# ✅ user_093: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_093/user_093.weights.h5
# ✅ user_094: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_094/user_094.weights.h5
# ✅ user_095: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_095/user_095.weights.h5
# ✅ user_096: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_096/user_096.weights.h5
# ✅ user_097: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_097/user_097.weights.h5
# ✅ user_098: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_098/user_098.weights.h5
# ✅ user_099: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_099/user_099.weights.h5
# ✅ user_100: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_100/user_100.weights.h5
# ✅ user_101: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_101/user_101.weights.h5
# ✅ user_102: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_102/user_102.weights.h5
# ✅ user_103: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_103/user_103.weights.h5
# ✅ user_104: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_104/user_104.weights.h5
# ✅ user_105: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_105/user_105.weights.h5
# ✅ user_106: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_106/user_106.weights.h5
# ✅ user_107: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_107/user_107.weights.h5
# ✅ user_108: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_108/user_108.weights.h5
# ✅ user_109: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_109/user_109.weights.h5
# ✅ user_110: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_110/user_110.weights.h5
# ✅ user_111: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_111/user_111.weights.h5
# ✅ user_112: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_112/user_112.weights.h5
# ✅ user_113: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_113/user_113.weights.h5
# ✅ user_114: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_114/user_114.weights.h5
# ✅ user_115: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_115/user_115.weights.h5
# ✅ user_116: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_116/user_116.weights.h5
# ✅ user_117: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_117/user_117.weights.h5
# ✅ user_118: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_118/user_118.weights.h5
# ✅ user_119: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_119/user_119.weights.h5
# ✅ user_120: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_120/user_120.weights.h5
# ✅ user_121: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_121/user_121.weights.h5
# ✅ user_122: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_122/user_122.weights.h5
# ✅ user_123: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_123/user_123.weights.h5
# ✅ user_124: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_124/user_124.weights.h5
# ✅ user_125: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_125/user_125.weights.h5
# ✅ user_126: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_126/user_126.weights.h5
# ✅ user_127: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_127/user_127.weights.h5
# ✅ user_128: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_128/user_128.weights.h5
# 🏃 Training LSTM users (128) …
# ✅ user_001: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_001/user_001.weights.h5
# ✅ user_002: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_002/user_002.weights.h5
# ✅ user_003: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_003/user_003.weights.h5
# ✅ user_004: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_004/user_004.weights.h5
# ✅ user_005: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_005/user_005.weights.h5
# ✅ user_006: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_006/user_006.weights.h5
# ✅ user_007: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_007/user_007.weights.h5
# ✅ user_008: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_008/user_008.weights.h5
# ✅ user_009: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_009/user_009.weights.h5
# ✅ user_010: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_010/user_010.weights.h5
# ✅ user_011: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_011/user_011.weights.h5
# ✅ user_012: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_012/user_012.weights.h5
# ✅ user_013: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_013/user_013.weights.h5
# ✅ user_014: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_014/user_014.weights.h5
# ✅ user_015: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_015/user_015.weights.h5
# ✅ user_016: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_016/user_016.weights.h5
# ✅ user_017: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_017/user_017.weights.h5
# ✅ user_018: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_018/user_018.weights.h5
# ✅ user_019: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_019/user_019.weights.h5
# ✅ user_020: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_020/user_020.weights.h5
# ✅ user_021: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_021/user_021.weights.h5
# ✅ user_022: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_022/user_022.weights.h5
# ✅ user_023: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_023/user_023.weights.h5
# ✅ user_024: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_024/user_024.weights.h5
# ✅ user_025: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_025/user_025.weights.h5
# ✅ user_026: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_026/user_026.weights.h5
# ✅ user_027: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_027/user_027.weights.h5
# ✅ user_028: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_028/user_028.weights.h5
# ✅ user_029: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_029/user_029.weights.h5
# ✅ user_030: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_030/user_030.weights.h5
# ✅ user_031: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_031/user_031.weights.h5
# ✅ user_032: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_032/user_032.weights.h5
# ✅ user_033: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_033/user_033.weights.h5
# ✅ user_034: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_034/user_034.weights.h5
# ✅ user_035: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_035/user_035.weights.h5
# ✅ user_036: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_036/user_036.weights.h5
# ✅ user_037: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_037/user_037.weights.h5
# ✅ user_038: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_038/user_038.weights.h5
# ✅ user_039: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_039/user_039.weights.h5
# ✅ user_040: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_040/user_040.weights.h5
# ✅ user_041: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_041/user_041.weights.h5
# ✅ user_042: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_042/user_042.weights.h5
# ✅ user_043: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_043/user_043.weights.h5
# ✅ user_044: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_044/user_044.weights.h5
# ✅ user_045: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_045/user_045.weights.h5
# ✅ user_046: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_046/user_046.weights.h5
# ✅ user_047: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_047/user_047.weights.h5
# ✅ user_048: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_048/user_048.weights.h5
# ✅ user_049: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_049/user_049.weights.h5
# ✅ user_050: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_050/user_050.weights.h5
# ✅ user_051: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_051/user_051.weights.h5
# ✅ user_052: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_052/user_052.weights.h5
# ✅ user_053: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_053/user_053.weights.h5
# ✅ user_054: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_054/user_054.weights.h5
# ✅ user_055: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_055/user_055.weights.h5
# ✅ user_056: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_056/user_056.weights.h5
# ✅ user_057: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_057/user_057.weights.h5
# ✅ user_058: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_058/user_058.weights.h5
# ✅ user_059: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_059/user_059.weights.h5
# ✅ user_060: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_060/user_060.weights.h5
# ✅ user_061: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_061/user_061.weights.h5
# ✅ user_062: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_062/user_062.weights.h5
# ✅ user_063: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_063/user_063.weights.h5
# ✅ user_064: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_064/user_064.weights.h5
# ✅ user_065: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_065/user_065.weights.h5
# ✅ user_066: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_066/user_066.weights.h5
# ✅ user_067: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_067/user_067.weights.h5
# ✅ user_068: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_068/user_068.weights.h5
# ✅ user_069: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_069/user_069.weights.h5
# ✅ user_070: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_070/user_070.weights.h5
# ✅ user_071: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_071/user_071.weights.h5
# ✅ user_072: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_072/user_072.weights.h5
# ✅ user_073: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_073/user_073.weights.h5
# ✅ user_074: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_074/user_074.weights.h5
# ✅ user_075: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_075/user_075.weights.h5
# ✅ user_076: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_076/user_076.weights.h5
# ✅ user_077: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_077/user_077.weights.h5
# ✅ user_078: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_078/user_078.weights.h5
# ✅ user_079: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_079/user_079.weights.h5
# ✅ user_080: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_080/user_080.weights.h5
# ✅ user_081: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_081/user_081.weights.h5
# ✅ user_082: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_082/user_082.weights.h5
# ✅ user_083: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_083/user_083.weights.h5
# ✅ user_084: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_084/user_084.weights.h5
# ✅ user_085: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_085/user_085.weights.h5
# ✅ user_086: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_086/user_086.weights.h5
# ✅ user_087: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_087/user_087.weights.h5
# ✅ user_088: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_088/user_088.weights.h5
# ✅ user_089: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_089/user_089.weights.h5
# ✅ user_090: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_090/user_090.weights.h5
# ✅ user_091: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_091/user_091.weights.h5
# ✅ user_092: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_092/user_092.weights.h5
# ✅ user_093: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_093/user_093.weights.h5
# ✅ user_094: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_094/user_094.weights.h5
# ✅ user_095: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_095/user_095.weights.h5
# ✅ user_096: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_096/user_096.weights.h5
# ✅ user_097: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_097/user_097.weights.h5
# ✅ user_098: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_098/user_098.weights.h5
# ✅ user_099: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_099/user_099.weights.h5
# ✅ user_100: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_100/user_100.weights.h5
# ✅ user_101: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_101/user_101.weights.h5
# ✅ user_102: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_102/user_102.weights.h5
# ✅ user_103: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_103/user_103.weights.h5
# ✅ user_104: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_104/user_104.weights.h5
# ✅ user_105: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_105/user_105.weights.h5
# ✅ user_106: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_106/user_106.weights.h5
# ✅ user_107: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_107/user_107.weights.h5
# ✅ user_108: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_108/user_108.weights.h5
# ✅ user_109: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_109/user_109.weights.h5
# ✅ user_110: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_110/user_110.weights.h5
# ✅ user_111: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_111/user_111.weights.h5
# ✅ user_112: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_112/user_112.weights.h5
# ✅ user_113: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_113/user_113.weights.h5
# ✅ user_114: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_114/user_114.weights.h5
# ✅ user_115: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_115/user_115.weights.h5
# ✅ user_116: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_116/user_116.weights.h5
# ✅ user_117: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_117/user_117.weights.h5
# ✅ user_118: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_118/user_118.weights.h5
# ✅ user_119: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_119/user_119.weights.h5
# ✅ user_120: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_120/user_120.weights.h5
# ✅ user_121: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_121/user_121.weights.h5
# ✅ user_122: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_122/user_122.weights.h5
# ✅ user_123: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_123/user_123.weights.h5
# ✅ user_124: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_124/user_124.weights.h5
# ✅ user_125: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_125/user_125.weights.h5
# ✅ user_126: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_126/user_126.weights.h5
# ✅ user_127: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_127/user_127.weights.h5
# ✅ user_128: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_128/user_128.weights.h5
# 🎉 Done.
