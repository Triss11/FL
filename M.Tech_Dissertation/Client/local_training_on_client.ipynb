# %%
import os
import json
import time
import base64
import pathlib
from typing import Dict, List, Optional, Tuple

import requests
import numpy as np
import pandas as pd
import tensorflow as tf

# %% [markdown]
# # Config for BC

# %%
OWNER = "Triss11"
REPO  = "FL"
REF   = "main"

# Download EXACTLY these two files:
FNN_MODEL_PATH  = "M.Tech_Dissertation/Server/global_model/global_FNN_model.keras"
LSTM_MODEL_PATH = "M.Tech_Dissertation/Server/global_model/global_lstm_model.keras"

# User data directories
FNN_USERS_DIR  = pathlib.Path("/Users/sohinikar/FL/M.Tech_Dissertation/Client/data/FNN_BC_test_data")
LSTM_USERS_DIR = pathlib.Path("/Users/sohinikar/FL/M.Tech_Dissertation/Client/data/LSTM_BC_test_data")

# Output roots (per-user subfolders created automatically)
FNN_OUT_ROOT  = pathlib.Path("/Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC")
LSTM_OUT_ROOT = pathlib.Path("/Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC")

# Training hyperparams
EPOCHS = 1
BATCH_SIZE = 8
OPTIMIZER = "adam"
METRICS = ["accuracy"]

# %%
def gh_session() -> requests.Session:
    s = requests.Session()
    token = os.environ.get("GITHUB_TOKEN")
    if token:
        s.headers.update({"Authorization": f"Bearer {token}"})
    s.headers.update({"Accept": "application/vnd.github+json"})
    return s


def get_github_file_entry(session: requests.Session, owner: str, repo: str, path: str, ref: str = "main") -> Dict:
    """Return the GitHub contents API JSON for a specific file path."""
    url = f"https://api.github.com/repos/{owner}/{repo}/contents/{path}?ref={ref}"
    r = session.get(url)
    if r.status_code != 200:
        raise RuntimeError(f"Could not fetch {path}: {r.status_code} {r.text}")
    entry = r.json()
    if entry.get("type") != "file" or not entry.get("download_url"):
        raise RuntimeError(f"{path} is not a downloadable file.")
    return entry


def download_file(session: requests.Session, entry: Dict, dest: pathlib.Path) -> pathlib.Path:
    """Download a file using 'download_url' from the GitHub contents API."""
    url = entry.get("download_url")
    if not url:
        raise RuntimeError(f"No download_url for {entry.get('name')}")
    dest.parent.mkdir(parents=True, exist_ok=True)
    r = session.get(url, stream=True)
    if r.status_code != 200:
        raise RuntimeError(f"Download failed for {entry.get('name')}: {r.status_code} {r.text}")
    with open(dest, "wb") as f:
        for chunk in r.iter_content(chunk_size=1024 * 1024):
            if chunk:
                f.write(chunk)
    return dest


def load_user_dirs(root: pathlib.Path) -> List[pathlib.Path]:
    """Return sorted list of user_* directories that contain X.csv and y.csv."""
    if not root.exists():
        return []
    users = []
    for p in sorted(root.glob("user_*")):
        if (p / "X.csv").exists() and (p / "y.csv").exists():
            users.append(p)
    return users


def _auto_pick_loss_and_cast_labels(model: tf.keras.Model, y: np.ndarray) -> (str, np.ndarray):
    """
    Choose an appropriate loss based on the model output shape.
    - If single output -> binary_crossentropy (float labels 0/1)
    - If multi-class outputs -> sparse_categorical_crossentropy (int labels 0..C-1)
    """
    out_shape = model.output_shape
    if isinstance(out_shape, (list, tuple)):
        out_shape = out_shape[0]
    if isinstance(out_shape, (list, tuple)) and len(out_shape) > 1:
        num_outputs = int(np.prod(out_shape[1:]))
    else:
        num_outputs = 1

    if num_outputs == 1:
        y = y.astype(np.float32).reshape(-1)
        return "binary_crossentropy", y
    else:
        y = y.astype(np.int32).reshape(-1)
        return "sparse_categorical_crossentropy", y


def train_one_user(model_path: pathlib.Path,
                   user_dir: pathlib.Path,
                   out_dir: pathlib.Path,
                   is_lstm: bool) -> Dict:
    """
    Load model, train on user data (no validation), save weights + params.json to out_dir.
    Automatically chooses the correct loss based on model output shape.
    """
    # Load data
    X = pd.read_csv(user_dir / "X.csv").to_numpy(dtype=np.float32)
    y = pd.read_csv(user_dir / "y.csv")["label"].to_numpy()

    if is_lstm:
        X = X.reshape((X.shape[0], 1, X.shape[1])).astype(np.float32)

    # Load model and pick loss
    model = tf.keras.models.load_model(str(model_path))
    chosen_loss, y = _auto_pick_loss_and_cast_labels(model, y)

    # Compile fresh (weights may not include optimizer state)
    model.compile(optimizer=OPTIMIZER, loss=chosen_loss, metrics=METRICS)

    # Train (no validation)
    start = time.time()
    hist = model.fit(X, y, epochs=EPOCHS, batch_size=BATCH_SIZE, verbose=0)
    elapsed = time.time() - start

    # Prepare output
    out_dir.mkdir(parents=True, exist_ok=True)
    weights_path = out_dir / f"{user_dir.name}.weights.h5"   # Keras 3 requires .weights.h5
    model.save_weights(str(weights_path))

    final_metrics = {f"final_{k}": float(v[-1]) for k, v in hist.history.items()}
    params = {
        "user": user_dir.name,
        "model_file": model_path.name,
        "samples": int(X.shape[0]),
        "features": int(X.shape[-1]),
        "is_lstm": is_lstm,
        "epochs": EPOCHS,
        "batch_size": BATCH_SIZE,
        "optimizer": OPTIMIZER,
        "loss": chosen_loss,
        "metrics": METRICS,
        "train_seconds": round(elapsed, 3),
        **final_metrics
    }
    with open(out_dir / "params.json", "w") as f:
        json.dump(params, f, indent=2)

    return {"weights": str(weights_path), "params": params}


def main():
    session = gh_session()

    # 1) Fetch exact global models from GitHub
    print("🔎 Fetching exact global models from GitHub…")
    fnn_entry  = get_github_file_entry(session, OWNER, REPO, FNN_MODEL_PATH, REF)
    lstm_entry = get_github_file_entry(session, OWNER, REPO, LSTM_MODEL_PATH, REF)

    # 2) Download them locally (cache under ./_downloaded_models)
    cache_dir = pathlib.Path("./_downloaded_models")
    fnn_local  = download_file(session, fnn_entry,  cache_dir / pathlib.Path(FNN_MODEL_PATH).name)
    lstm_local = download_file(session, lstm_entry, cache_dir / pathlib.Path(LSTM_MODEL_PATH).name)
    print(f"⬇️  Downloaded FNN model:  {fnn_local}")
    print(f"⬇️  Downloaded LSTM model: {lstm_local}")

    # 3) Enumerate users
    fnn_users  = load_user_dirs(FNN_USERS_DIR)
    lstm_users = load_user_dirs(LSTM_USERS_DIR)

    if not fnn_users:
        print(f"⚠️  No valid FNN user folders found under: {FNN_USERS_DIR}")
    if not lstm_users:
        print(f"⚠️  No valid LSTM user folders found under: {LSTM_USERS_DIR}")

    # Collect times for summary
    fnn_times: List[float] = []
    lstm_times: List[float] = []

    # 4) Train FNN users
    print(f"🏃 Training FNN users ({len(fnn_users)}) …")
    for udir in fnn_users:
        out_dir = FNN_OUT_ROOT / udir.name
        try:
            result = train_one_user(fnn_local, udir, out_dir, is_lstm=False)
            secs = float(result["params"]["train_seconds"])
            fnn_times.append(secs)
            print(f"✅ {udir.name}: saved -> {result['weights']}  ({secs:.3f}s)")
        except Exception as e:
            print(f"❌ {udir.name}: {e}")

    # 5) Train LSTM users
    print(f"🏃 Training LSTM users ({len(lstm_users)}) …")
    for udir in lstm_users:
        out_dir = LSTM_OUT_ROOT / udir.name
        try:
            result = train_one_user(lstm_local, udir, out_dir, is_lstm=True)
            secs = float(result["params"]["train_seconds"])
            lstm_times.append(secs)
            print(f"✅ {udir.name}: saved -> {result['weights']}  ({secs:.3f}s)")
        except Exception as e:
            print(f"❌ {udir.name}: {e}")

    # 6) Print summaries
    if fnn_times:
        print("\n⏱️ FNN training time summary:")
        print(f"   Users trained: {len(fnn_times)}")
        print(f"   Avg: {sum(fnn_times)/len(fnn_times):.3f}s   Min: {min(fnn_times):.3f}s   Max: {max(fnn_times):.3f}s")

    if lstm_times:
        print("\n⏱️ LSTM training time summary:")
        print(f"   Users trained: {len(lstm_times)}")
        print(f"   Avg: {sum(lstm_times)/len(lstm_times):.3f}s   Min: {min(lstm_times):.3f}s   Max: {max(lstm_times):.3f}s")

    print("\n🎉 Done.")


if __name__ == "__main__":
    main()
# Out:
# 🔎 Fetching exact global models from GitHub…
# ⬇️  Downloaded FNN model:  _downloaded_models/global_FNN_model.keras
# ⬇️  Downloaded LSTM model: _downloaded_models/global_lstm_model.keras
# 🏃 Training FNN users (128) …
# ✅ user_001: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_001/user_001.weights.h5  (0.457s)
# ✅ user_002: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_002/user_002.weights.h5  (0.413s)
# ✅ user_003: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_003/user_003.weights.h5  (0.420s)
# ✅ user_004: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_004/user_004.weights.h5  (0.383s)
# ✅ user_005: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_005/user_005.weights.h5  (0.374s)
# ✅ user_006: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_006/user_006.weights.h5  (0.370s)
# ✅ user_007: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_007/user_007.weights.h5  (0.370s)
# ✅ user_008: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_008/user_008.weights.h5  (0.391s)
# ✅ user_009: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_009/user_009.weights.h5  (0.384s)
# ✅ user_010: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_010/user_010.weights.h5  (0.386s)
# ✅ user_011: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_011/user_011.weights.h5  (0.377s)
# ✅ user_012: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_012/user_012.weights.h5  (0.381s)
# ✅ user_013: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_013/user_013.weights.h5  (0.362s)
# ✅ user_014: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_014/user_014.weights.h5  (0.365s)
# ✅ user_015: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_015/user_015.weights.h5  (0.368s)
# ✅ user_016: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_016/user_016.weights.h5  (0.368s)
# ✅ user_017: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_017/user_017.weights.h5  (0.368s)
# ✅ user_018: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_018/user_018.weights.h5  (0.371s)
# ✅ user_019: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_019/user_019.weights.h5  (0.372s)
# ✅ user_020: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_020/user_020.weights.h5  (0.366s)
# ✅ user_021: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_021/user_021.weights.h5  (0.373s)
# ✅ user_022: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_022/user_022.weights.h5  (0.363s)
# ✅ user_023: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_023/user_023.weights.h5  (0.376s)
# ✅ user_024: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_024/user_024.weights.h5  (0.371s)
# ✅ user_025: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_025/user_025.weights.h5  (0.372s)
# ✅ user_026: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_026/user_026.weights.h5  (0.379s)
# ✅ user_027: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_027/user_027.weights.h5  (0.366s)
# ✅ user_028: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_028/user_028.weights.h5  (0.394s)
# ✅ user_029: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_029/user_029.weights.h5  (0.368s)
# ✅ user_030: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_030/user_030.weights.h5  (0.373s)
# ✅ user_031: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_031/user_031.weights.h5  (0.375s)
# ✅ user_032: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_032/user_032.weights.h5  (0.402s)
# ✅ user_033: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_033/user_033.weights.h5  (0.410s)
# ✅ user_034: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_034/user_034.weights.h5  (0.380s)
# ✅ user_035: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_035/user_035.weights.h5  (0.375s)
# ✅ user_036: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_036/user_036.weights.h5  (0.381s)
# ✅ user_037: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_037/user_037.weights.h5  (0.381s)
# ✅ user_038: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_038/user_038.weights.h5  (0.393s)
# ✅ user_039: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_039/user_039.weights.h5  (0.412s)
# ✅ user_040: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_040/user_040.weights.h5  (0.412s)
# ✅ user_041: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_041/user_041.weights.h5  (0.415s)
# ✅ user_042: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_042/user_042.weights.h5  (0.411s)
# ✅ user_043: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_043/user_043.weights.h5  (0.414s)
# ✅ user_044: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_044/user_044.weights.h5  (0.413s)
# ✅ user_045: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_045/user_045.weights.h5  (0.413s)
# ✅ user_046: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_046/user_046.weights.h5  (0.423s)
# ✅ user_047: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_047/user_047.weights.h5  (0.418s)
# ✅ user_048: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_048/user_048.weights.h5  (0.412s)
# ✅ user_049: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_049/user_049.weights.h5  (0.416s)
# ✅ user_050: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_050/user_050.weights.h5  (1.878s)
# ✅ user_051: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_051/user_051.weights.h5  (0.480s)
# ✅ user_052: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_052/user_052.weights.h5  (0.453s)
# ✅ user_053: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_053/user_053.weights.h5  (0.452s)
# ✅ user_054: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_054/user_054.weights.h5  (0.452s)
# ✅ user_055: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_055/user_055.weights.h5  (0.394s)
# ✅ user_056: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_056/user_056.weights.h5  (0.386s)
# ✅ user_057: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_057/user_057.weights.h5  (0.375s)
# ✅ user_058: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_058/user_058.weights.h5  (0.378s)
# ✅ user_059: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_059/user_059.weights.h5  (0.379s)
# ✅ user_060: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_060/user_060.weights.h5  (0.391s)
# ✅ user_061: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_061/user_061.weights.h5  (0.364s)
# ✅ user_062: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_062/user_062.weights.h5  (0.375s)
# ✅ user_063: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_063/user_063.weights.h5  (0.364s)
# ✅ user_064: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_064/user_064.weights.h5  (0.369s)
# ✅ user_065: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_065/user_065.weights.h5  (0.367s)
# ✅ user_066: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_066/user_066.weights.h5  (0.365s)
# ✅ user_067: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_067/user_067.weights.h5  (0.365s)
# ✅ user_068: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_068/user_068.weights.h5  (0.368s)
# ✅ user_069: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_069/user_069.weights.h5  (0.357s)
# ✅ user_070: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_070/user_070.weights.h5  (0.362s)
# ✅ user_071: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_071/user_071.weights.h5  (0.366s)
# ✅ user_072: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_072/user_072.weights.h5  (0.357s)
# ✅ user_073: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_073/user_073.weights.h5  (0.363s)
# ✅ user_074: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_074/user_074.weights.h5  (0.355s)
# ✅ user_075: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_075/user_075.weights.h5  (0.359s)
# ✅ user_076: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_076/user_076.weights.h5  (0.360s)
# ✅ user_077: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_077/user_077.weights.h5  (0.364s)
# ✅ user_078: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_078/user_078.weights.h5  (0.360s)
# ✅ user_079: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_079/user_079.weights.h5  (0.356s)
# ✅ user_080: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_080/user_080.weights.h5  (0.362s)
# ✅ user_081: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_081/user_081.weights.h5  (0.374s)
# ✅ user_082: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_082/user_082.weights.h5  (0.378s)
# ✅ user_083: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_083/user_083.weights.h5  (0.372s)
# ✅ user_084: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_084/user_084.weights.h5  (0.373s)
# ✅ user_085: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_085/user_085.weights.h5  (0.362s)
# ✅ user_086: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_086/user_086.weights.h5  (0.354s)
# ✅ user_087: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_087/user_087.weights.h5  (0.359s)
# ✅ user_088: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_088/user_088.weights.h5  (0.354s)
# ✅ user_089: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_089/user_089.weights.h5  (0.359s)
# ✅ user_090: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_090/user_090.weights.h5  (0.353s)
# ✅ user_091: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_091/user_091.weights.h5  (0.357s)
# ✅ user_092: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_092/user_092.weights.h5  (0.362s)
# ✅ user_093: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_093/user_093.weights.h5  (0.357s)
# ✅ user_094: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_094/user_094.weights.h5  (0.363s)
# ✅ user_095: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_095/user_095.weights.h5  (0.353s)
# ✅ user_096: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_096/user_096.weights.h5  (0.355s)
# ✅ user_097: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_097/user_097.weights.h5  (0.354s)
# ✅ user_098: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_098/user_098.weights.h5  (0.358s)
# ✅ user_099: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_099/user_099.weights.h5  (0.357s)
# ✅ user_100: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_100/user_100.weights.h5  (0.358s)
# ✅ user_101: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_101/user_101.weights.h5  (0.355s)
# ✅ user_102: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_102/user_102.weights.h5  (0.354s)
# ✅ user_103: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_103/user_103.weights.h5  (0.359s)
# ✅ user_104: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_104/user_104.weights.h5  (0.356s)
# ✅ user_105: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_105/user_105.weights.h5  (0.361s)
# ✅ user_106: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_106/user_106.weights.h5  (0.407s)
# ✅ user_107: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_107/user_107.weights.h5  (0.369s)
# ✅ user_108: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_108/user_108.weights.h5  (0.384s)
# ✅ user_109: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_109/user_109.weights.h5  (0.444s)
# ✅ user_110: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_110/user_110.weights.h5  (0.454s)
# ✅ user_111: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_111/user_111.weights.h5  (0.480s)
# ✅ user_112: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_112/user_112.weights.h5  (0.443s)
# ✅ user_113: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_113/user_113.weights.h5  (0.452s)
# ✅ user_114: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_114/user_114.weights.h5  (0.462s)
# ✅ user_115: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_115/user_115.weights.h5  (0.443s)
# ✅ user_116: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_116/user_116.weights.h5  (0.421s)
# ✅ user_117: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_117/user_117.weights.h5  (0.412s)
# ✅ user_118: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_118/user_118.weights.h5  (0.413s)
# ✅ user_119: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_119/user_119.weights.h5  (0.422s)
# ✅ user_120: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_120/user_120.weights.h5  (0.420s)
# ✅ user_121: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_121/user_121.weights.h5  (0.413s)
# ✅ user_122: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_122/user_122.weights.h5  (0.418s)
# ✅ user_123: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_123/user_123.weights.h5  (0.424s)
# ✅ user_124: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_124/user_124.weights.h5  (0.425s)
# ✅ user_125: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_125/user_125.weights.h5  (0.426s)
# ✅ user_126: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_126/user_126.weights.h5  (2.259s)
# ✅ user_127: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_127/user_127.weights.h5  (0.461s)
# ✅ user_128: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_BC/user_128/user_128.weights.h5  (0.404s)
# 🏃 Training LSTM users (128) …
# ✅ user_001: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_001/user_001.weights.h5  (0.543s)
# ✅ user_002: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_002/user_002.weights.h5  (0.527s)
# ✅ user_003: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_003/user_003.weights.h5  (0.524s)
# ✅ user_004: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_004/user_004.weights.h5  (0.525s)
# ✅ user_005: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_005/user_005.weights.h5  (0.528s)
# ✅ user_006: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_006/user_006.weights.h5  (0.520s)
# ✅ user_007: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_007/user_007.weights.h5  (0.516s)
# ✅ user_008: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_008/user_008.weights.h5  (0.514s)
# ✅ user_009: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_009/user_009.weights.h5  (0.530s)
# ✅ user_010: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_010/user_010.weights.h5  (0.522s)
# ✅ user_011: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_011/user_011.weights.h5  (0.522s)
# ✅ user_012: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_012/user_012.weights.h5  (0.531s)
# ✅ user_013: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_013/user_013.weights.h5  (0.520s)
# ✅ user_014: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_014/user_014.weights.h5  (0.526s)
# ✅ user_015: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_015/user_015.weights.h5  (0.515s)
# ✅ user_016: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_016/user_016.weights.h5  (0.524s)
# ✅ user_017: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_017/user_017.weights.h5  (0.522s)
# ✅ user_018: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_018/user_018.weights.h5  (0.549s)
# ✅ user_019: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_019/user_019.weights.h5  (0.528s)
# ✅ user_020: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_020/user_020.weights.h5  (0.532s)
# ✅ user_021: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_021/user_021.weights.h5  (0.526s)
# ✅ user_022: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_022/user_022.weights.h5  (0.513s)
# ✅ user_023: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_023/user_023.weights.h5  (0.520s)
# ✅ user_024: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_024/user_024.weights.h5  (0.517s)
# ✅ user_025: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_025/user_025.weights.h5  (0.526s)
# ✅ user_026: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_026/user_026.weights.h5  (0.519s)
# ✅ user_027: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_027/user_027.weights.h5  (0.526s)
# ✅ user_028: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_028/user_028.weights.h5  (0.518s)
# ✅ user_029: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_029/user_029.weights.h5  (0.516s)
# ✅ user_030: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_030/user_030.weights.h5  (0.523s)
# ✅ user_031: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_031/user_031.weights.h5  (0.518s)
# ✅ user_032: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_032/user_032.weights.h5  (0.519s)
# ✅ user_033: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_033/user_033.weights.h5  (0.520s)
# ✅ user_034: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_034/user_034.weights.h5  (0.517s)
# ✅ user_035: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_035/user_035.weights.h5  (0.528s)
# ✅ user_036: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_036/user_036.weights.h5  (0.514s)
# ✅ user_037: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_037/user_037.weights.h5  (0.520s)
# ✅ user_038: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_038/user_038.weights.h5  (0.516s)
# ✅ user_039: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_039/user_039.weights.h5  (0.521s)
# ✅ user_040: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_040/user_040.weights.h5  (0.517s)
# ✅ user_041: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_041/user_041.weights.h5  (0.529s)
# ✅ user_042: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_042/user_042.weights.h5  (0.579s)
# ✅ user_043: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_043/user_043.weights.h5  (0.522s)
# ✅ user_044: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_044/user_044.weights.h5  (0.519s)
# ✅ user_045: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_045/user_045.weights.h5  (0.519s)
# ✅ user_046: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_046/user_046.weights.h5  (0.520s)
# ✅ user_047: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_047/user_047.weights.h5  (0.546s)
# ✅ user_048: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_048/user_048.weights.h5  (0.536s)
# ✅ user_049: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_049/user_049.weights.h5  (0.533s)
# ✅ user_050: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_050/user_050.weights.h5  (0.522s)
# ✅ user_051: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_051/user_051.weights.h5  (0.520s)
# ✅ user_052: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_052/user_052.weights.h5  (0.522s)
# ✅ user_053: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_053/user_053.weights.h5  (0.551s)
# ✅ user_054: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_054/user_054.weights.h5  (0.529s)
# ✅ user_055: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_055/user_055.weights.h5  (0.550s)
# ✅ user_056: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_056/user_056.weights.h5  (0.539s)
# ✅ user_057: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_057/user_057.weights.h5  (0.528s)
# ✅ user_058: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_058/user_058.weights.h5  (0.525s)
# ✅ user_059: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_059/user_059.weights.h5  (0.528s)
# ✅ user_060: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_060/user_060.weights.h5  (0.520s)
# ✅ user_061: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_061/user_061.weights.h5  (0.529s)
# ✅ user_062: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_062/user_062.weights.h5  (0.525s)
# ✅ user_063: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_063/user_063.weights.h5  (0.519s)
# ✅ user_064: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_064/user_064.weights.h5  (2.480s)
# ✅ user_065: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_065/user_065.weights.h5  (0.533s)
# ✅ user_066: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_066/user_066.weights.h5  (0.564s)
# ✅ user_067: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_067/user_067.weights.h5  (0.540s)
# ✅ user_068: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_068/user_068.weights.h5  (0.542s)
# ✅ user_069: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_069/user_069.weights.h5  (0.536s)
# ✅ user_070: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_070/user_070.weights.h5  (0.572s)
# ✅ user_071: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_071/user_071.weights.h5  (0.538s)
# ✅ user_072: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_072/user_072.weights.h5  (0.548s)
# ✅ user_073: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_073/user_073.weights.h5  (0.534s)
# ✅ user_074: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_074/user_074.weights.h5  (0.524s)
# ✅ user_075: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_075/user_075.weights.h5  (0.520s)
# ✅ user_076: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_076/user_076.weights.h5  (0.524s)
# ✅ user_077: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_077/user_077.weights.h5  (0.530s)
# ✅ user_078: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_078/user_078.weights.h5  (0.527s)
# ✅ user_079: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_079/user_079.weights.h5  (0.582s)
# ✅ user_080: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_080/user_080.weights.h5  (0.526s)
# ✅ user_081: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_081/user_081.weights.h5  (0.516s)
# ✅ user_082: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_082/user_082.weights.h5  (0.527s)
# ✅ user_083: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_083/user_083.weights.h5  (0.519s)
# ✅ user_084: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_084/user_084.weights.h5  (0.616s)
# ✅ user_085: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_085/user_085.weights.h5  (0.521s)
# ✅ user_086: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_086/user_086.weights.h5  (0.514s)
# ✅ user_087: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_087/user_087.weights.h5  (0.526s)
# ✅ user_088: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_088/user_088.weights.h5  (0.517s)
# ✅ user_089: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_089/user_089.weights.h5  (0.517s)
# ✅ user_090: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_090/user_090.weights.h5  (0.524s)
# ✅ user_091: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_091/user_091.weights.h5  (0.522s)
# ✅ user_092: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_092/user_092.weights.h5  (0.518s)
# ✅ user_093: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_093/user_093.weights.h5  (0.527s)
# ✅ user_094: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_094/user_094.weights.h5  (0.519s)
# ✅ user_095: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_095/user_095.weights.h5  (0.518s)
# ✅ user_096: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_096/user_096.weights.h5  (0.515s)
# ✅ user_097: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_097/user_097.weights.h5  (0.515s)
# ✅ user_098: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_098/user_098.weights.h5  (0.520s)
# ✅ user_099: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_099/user_099.weights.h5  (0.514s)
# ✅ user_100: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_100/user_100.weights.h5  (0.528s)
# ✅ user_101: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_101/user_101.weights.h5  (0.535s)
# ✅ user_102: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_102/user_102.weights.h5  (0.536s)
# ✅ user_103: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_103/user_103.weights.h5  (0.517s)
# ✅ user_104: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_104/user_104.weights.h5  (0.529s)
# ✅ user_105: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_105/user_105.weights.h5  (0.511s)
# ✅ user_106: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_106/user_106.weights.h5  (0.509s)
# ✅ user_107: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_107/user_107.weights.h5  (0.518s)
# ✅ user_108: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_108/user_108.weights.h5  (0.523s)
# ✅ user_109: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_109/user_109.weights.h5  (0.518s)
# ✅ user_110: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_110/user_110.weights.h5  (0.514s)
# ✅ user_111: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_111/user_111.weights.h5  (0.524s)
# ✅ user_112: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_112/user_112.weights.h5  (0.521s)
# ✅ user_113: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_113/user_113.weights.h5  (0.515s)
# ✅ user_114: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_114/user_114.weights.h5  (0.525s)
# ✅ user_115: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_115/user_115.weights.h5  (0.516s)
# ✅ user_116: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_116/user_116.weights.h5  (0.524s)
# ✅ user_117: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_117/user_117.weights.h5  (0.512s)
# ✅ user_118: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_118/user_118.weights.h5  (0.516s)
# ✅ user_119: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_119/user_119.weights.h5  (0.514s)
# ✅ user_120: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_120/user_120.weights.h5  (0.514s)
# ✅ user_121: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_121/user_121.weights.h5  (0.521s)
# ✅ user_122: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_122/user_122.weights.h5  (0.514s)
# ✅ user_123: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_123/user_123.weights.h5  (0.521s)
# ✅ user_124: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_124/user_124.weights.h5  (0.520s)
# ✅ user_125: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_125/user_125.weights.h5  (0.513s)
# ✅ user_126: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_126/user_126.weights.h5  (0.516s)
# ✅ user_127: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_127/user_127.weights.h5  (0.517s)
# ✅ user_128: saved -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_BC/user_128/user_128.weights.h5  (0.512s)
#
# ⏱️ FNN training time summary:
#    Users trained: 128
#    Avg: 0.414s   Min: 0.353s   Max: 2.259s
#
# ⏱️ LSTM training time summary:
#    Users trained: 128
#    Avg: 0.541s   Min: 0.509s   Max: 2.480s
#
# 🎉 Done.

# %%
#!/usr/bin/env python3
"""
Client-side trainer for per-user updates (Multiclass: FNN + LSTM) with robust loss/metric handling.

Downloads EXACT models from:
  - M.Tech_Dissertation/Server/global_model/global_FNN_MC_model.keras
  - M.Tech_Dissertation/Server/global_model/global_lstm_MC_model.keras

Trains on users found under:
  - /Users/sohinikar/FL/M.Tech_Dissertation/Client/data/FNN_MC_test_data/user_*/
  - /Users/sohinikar/FL/M.Tech_Dissertation/Client/data/LSTM_MC_test_data/user_*/

Saves per-user outputs to:
  - /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_MC/user_xxx/
  - /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_MC/user_xxx/

Also prints average/min/max train times per family.

Env (if repo is private): export GITHUB_TOKEN=...
Deps: pip install tensorflow pandas requests
"""

import os, json, time, pathlib
from typing import Dict, List, Tuple, Optional

import numpy as np
import pandas as pd
import requests
import tensorflow as tf

# ---------------- CONFIG (Multiclass) ----------------
OWNER = "Triss11"
REPO  = "FL"
REF   = "main"

FNN_MODEL_PATH  = "M.Tech_Dissertation/Server/global_model/global_FNN_MC_model.keras"
LSTM_MODEL_PATH = "M.Tech_Dissertation/Server/global_model/global_lstm_MC_model.keras"

FNN_USERS_DIR  = pathlib.Path("/Users/sohinikar/FL/M.Tech_Dissertation/Client/data/FNN_MC_test_data")
LSTM_USERS_DIR = pathlib.Path("/Users/sohinikar/FL/M.Tech_Dissertation/Client/data/LSTM_MC_test_data")

FNN_OUT_ROOT  = pathlib.Path("/Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_MC")
LSTM_OUT_ROOT = pathlib.Path("/Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_MC")

EPOCHS = 5
BATCH_SIZE = 64
OPTIMIZER = "adam"
# -----------------------------------------------------


def gh_session() -> requests.Session:
    s = requests.Session()
    tok = os.environ.get("GITHUB_TOKEN")
    if tok:
        s.headers.update({"Authorization": f"Bearer {tok}"})
    s.headers.update({"Accept": "application/vnd.github+json"})
    return s


def get_github_file_entry(session: requests.Session, owner: str, repo: str, path: str, ref: str = "main") -> Dict:
    url = f"https://api.github.com/repos/{owner}/{repo}/contents/{path}?ref={ref}"
    r = session.get(url)
    if r.status_code != 200:
        raise RuntimeError(f"Could not fetch {path}: {r.status_code} {r.text}")
    entry = r.json()
    if entry.get("type") != "file" or not entry.get("download_url"):
        raise RuntimeError(f"{path} is not a downloadable file.")
    return entry


def download_file(session: requests.Session, entry: Dict, dest: pathlib.Path) -> pathlib.Path:
    url = entry.get("download_url")
    dest.parent.mkdir(parents=True, exist_ok=True)
    r = session.get(url, stream=True)
    if r.status_code != 200:
        raise RuntimeError(f"Download failed for {entry.get('name')}: {r.status_code} {r.text}")
    with open(dest, "wb") as f:
        for chunk in r.iter_content(1024 * 1024):
            if chunk:
                f.write(chunk)
    return dest


def load_user_dirs(root: pathlib.Path) -> List[pathlib.Path]:
    if not root.exists():
        return []
    users = []
    for p in sorted(root.glob("user_*")):
        if (p / "X.csv").exists() and (p / "y.csv").exists():
            users.append(p)
    return users


def _infer_output_info(model: tf.keras.Model, X_batch: np.ndarray) -> Tuple[int, bool]:
    """
    Robustly infer (num_outputs, from_logits) by doing a 1-sample forward pass.
    Falls back to last layer .units if needed.
    """
    # Try to build via forward pass
    try:
        yhat = model(tf.convert_to_tensor(X_batch[:1]), training=False)
        y0 = yhat[0] if isinstance(yhat, (list, tuple)) else yhat
        shp = tuple(y0.shape)  # e.g., (1, 4)
        num_outputs = int(np.prod(shp[1:])) if len(shp) > 1 else 1
    except Exception:
        # Fallback: use last layer units if available
        last = model.layers[-1]
        num_outputs = int(getattr(last, "units", 1))

    # Decide logits vs activated from the last layer
    last = model.layers[-1]
    act = getattr(last, "activation", None)
    act_name = getattr(act, "__name__", None)
    from_logits = (act_name in (None, "linear"))

    return num_outputs, from_logits


def _sanitize_labels(y: np.ndarray) -> Tuple[np.ndarray, Optional[Dict[int, int]]]:
    """Ensure y are integer class IDs 0..C-1. Convert strings/floats if needed."""
    y = np.asarray(y)
    if y.dtype.kind in {"U", "S", "O"}:
        classes, inv = np.unique(y, return_inverse=True)
        return inv.astype(np.int32), {i: int(c) for i, c in enumerate(classes)}
    if y.dtype.kind == "f":
        return np.rint(y).astype(np.int32), None
    return y.astype(np.int32), None


def _choose_loss_and_metrics(num_outputs: int, from_logits: bool):
    """Return (loss_fn, metrics_list) objects appropriate for the model."""
    if num_outputs == 1:
        loss_fn = tf.keras.losses.BinaryCrossentropy(from_logits=from_logits)
        metrics = [tf.keras.metrics.BinaryAccuracy(name="binary_accuracy")]
    else:
        loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=from_logits)
        metrics = [tf.keras.metrics.SparseCategoricalAccuracy(name="sparse_categorical_accuracy")]
    return loss_fn, metrics


def train_one_user(model_path: pathlib.Path,
                   user_dir: pathlib.Path,
                   out_dir: pathlib.Path,
                   is_lstm: bool) -> Dict:
    # Load data
    X = pd.read_csv(user_dir / "X.csv").to_numpy(dtype=np.float32)
    y = pd.read_csv(user_dir / "y.csv")["label"].to_numpy()

    if is_lstm:
        X = X.reshape((X.shape[0], 1, X.shape[1])).astype(np.float32)

    # Load model
    model = tf.keras.models.load_model(str(model_path))

    # >>> NEW: infer outputs AFTER we have X shaped, using a forward pass
    num_outputs, from_logits = _infer_output_info(model, X)

    # Sanitize labels
    if num_outputs == 1:
        # Binary
        if y.dtype.kind in {"U", "S", "O"}:
            # strings -> indices 0/1
            classes, inv = np.unique(y, return_inverse=True)
            y_train = inv.astype(np.float32).reshape(-1)
        else:
            y_train = y.astype(np.float32).reshape(-1)
        loss_fn  = tf.keras.losses.BinaryCrossentropy(from_logits=from_logits)
        metrics  = [tf.keras.metrics.BinaryAccuracy(name="binary_accuracy")]
    else:
        # Multiclass sparse
        if y.ndim == 2 and y.shape[1] > 1:
            # one-hot -> class ids
            y_train = y.argmax(axis=1).astype(np.int32).reshape(-1)
        elif y.dtype.kind in {"U", "S", "O"}:
            # strings -> class ids
            classes, inv = np.unique(y, return_inverse=True)
            y_train = inv.astype(np.int32).reshape(-1)
        elif y.dtype.kind == "f":
            # floats -> round to nearest class id
            y_train = np.rint(y).astype(np.int32).reshape(-1)
        else:
            y_train = y.astype(np.int32).reshape(-1)
        loss_fn  = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=from_logits)
        metrics  = [tf.keras.metrics.SparseCategoricalAccuracy(name="sparse_categorical_accuracy")]

    # Compile & train
    model.compile(optimizer=OPTIMIZER, loss=loss_fn, metrics=metrics)
    print(f"→ {user_dir.name}: X{X.shape}, y{y_train.shape}, outputs={num_outputs}, "
          f"from_logits={from_logits}, loss={loss_fn.name}, metric={[m.name for m in metrics]}")

    start = time.time()
    try:
        hist = model.fit(X, y_train, epochs=EPOCHS, batch_size=BATCH_SIZE, verbose=0)
    except Exception as e:
        if "same rank" in str(e) or "ranks" in str(e):
            print(f"   ⚠️  {user_dir.name}: metric rank issue -> retrying with no metrics")
            model.compile(optimizer=OPTIMIZER, loss=loss_fn, metrics=[])
            hist = model.fit(X, y_train, epochs=EPOCHS, batch_size=BATCH_SIZE, verbose=0)
        else:
            raise
    elapsed = time.time() - start

    # Save weights + params (unchanged)
    out_dir.mkdir(parents=True, exist_ok=True)
    weights_path = out_dir / f"{user_dir.name}.weights.h5"
    model.save_weights(str(weights_path))
    final_metrics = {f"final_{k}": float(v[-1]) for k, v in getattr(hist, "history", {}).items()}
    params = {
        "user": user_dir.name,
        "model_file": model_path.name,
        "samples": int(X.shape[0]),
        "features": int(X.shape[-1]),
        "is_lstm": is_lstm,
        "epochs": EPOCHS,
        "batch_size": BATCH_SIZE,
        "optimizer": OPTIMIZER,
        "loss": loss_fn.name,
        "metrics": [m.name for m in metrics],
        "train_seconds": round(elapsed, 3),
        **final_metrics
    }
    with open(out_dir / "params.json", "w") as f:
        json.dump(params, f, indent=2)

    return {"weights": str(weights_path), "params": params}



def main():
    session = gh_session()

    # 1) Download exact MC models
    print("🔎 Fetching exact multiclass global models from GitHub…")
    fnn_entry  = get_github_file_entry(session, OWNER, REPO, FNN_MODEL_PATH, REF)
    lstm_entry = get_github_file_entry(session, OWNER, REPO, LSTM_MODEL_PATH, REF)

    cache_dir = pathlib.Path("./_downloaded_models")
    fnn_local  = download_file(session, fnn_entry,  cache_dir / pathlib.Path(FNN_MODEL_PATH).name)
    lstm_local = download_file(session, lstm_entry, cache_dir / pathlib.Path(LSTM_MODEL_PATH).name)
    print(f"⬇️  FNN MC model:  {fnn_local}")
    print(f"⬇️  LSTM MC model: {lstm_local}")

    # 2) Enumerate user folders
    fnn_users  = load_user_dirs(FNN_USERS_DIR)
    lstm_users = load_user_dirs(LSTM_USERS_DIR)

    if not fnn_users:
        print(f"⚠️  No valid FNN user folders found under: {FNN_USERS_DIR}")
    if not lstm_users:
        print(f"⚠️  No valid LSTM user folders found under: {LSTM_USERS_DIR}")

    fnn_times: List[float] = []
    lstm_times: List[float] = []

    # 3) Train FNN users
    print(f"🏃 Training FNN (MC) users ({len(fnn_users)}) …")
    for udir in fnn_users:
        out_dir = FNN_OUT_ROOT / udir.name
        try:
            result = train_one_user(fnn_local, udir, out_dir, is_lstm=False)
            secs = float(result["params"]["train_seconds"])
            fnn_times.append(secs)
            print(f"✅ {udir.name}: {secs:.3f}s  -> {result['weights']}")
        except Exception as e:
            print(f"❌ {udir.name}: {e}")

    # 4) Train LSTM users
    print(f"🏃 Training LSTM (MC) users ({len(lstm_users)}) …")
    for udir in lstm_users:
        out_dir = LSTM_OUT_ROOT / udir.name
        try:
            result = train_one_user(lstm_local, udir, out_dir, is_lstm=True)
            secs = float(result["params"]["train_seconds"])
            lstm_times.append(secs)
            print(f"✅ {udir.name}: {secs:.3f}s  -> {result['weights']}")
        except Exception as e:
            print(f"❌ {udir.name}: {e}")

    # 5) Summaries
    if fnn_times:
        print("\n⏱️ FNN (MC) training time summary:")
        print(f"   Users trained: {len(fnn_times)}")
        print(f"   Avg: {sum(fnn_times)/len(fnn_times):.3f}s   Min: {min(fnn_times):.3f}s   Max: {max(fnn_times):.3f}s")

    if lstm_times:
        print("\n⏱️ LSTM (MC) training time summary:")
        print(f"   Users trained: {len(lstm_times)}")
        print(f"   Avg: {sum(lstm_times)/len(lstm_times):.3f}s   Min: {min(lstm_times):.3f}s   Max: {max(lstm_times):.3f}s")

    print("\n🎉 Done.")


if __name__ == "__main__":
    main()
# Out:
# 🔎 Fetching exact multiclass global models from GitHub…
# ⬇️  FNN MC model:  _downloaded_models/global_FNN_MC_model.keras
# ⬇️  LSTM MC model: _downloaded_models/global_lstm_MC_model.keras
# 🏃 Training FNN (MC) users (128) …
# → user_001: X(46, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_001: 0.427s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_MC/user_001/user_001.weights.h5
# → user_002: X(46, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_002: 0.421s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_MC/user_002/user_002.weights.h5
# → user_003: X(46, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_003: 0.415s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_MC/user_003/user_003.weights.h5
# → user_004: X(46, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_004: 0.433s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_MC/user_004/user_004.weights.h5
# → user_005: X(46, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_005: 0.407s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_MC/user_005/user_005.weights.h5
# → user_006: X(46, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_006: 0.419s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_MC/user_006/user_006.weights.h5
# → user_007: X(46, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_007: 0.403s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_MC/user_007/user_007.weights.h5
# → user_008: X(46, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_008: 0.429s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_MC/user_008/user_008.weights.h5
# → user_009: X(46, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_009: 0.411s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_MC/user_009/user_009.weights.h5
# → user_010: X(46, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_010: 0.434s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_MC/user_010/user_010.weights.h5
# → user_011: X(46, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_011: 0.454s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_MC/user_011/user_011.weights.h5
# → user_012: X(46, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_012: 0.491s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_MC/user_012/user_012.weights.h5
# → user_013: X(46, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_013: 0.440s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_MC/user_013/user_013.weights.h5
# → user_014: X(46, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_014: 0.403s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_MC/user_014/user_014.weights.h5
# → user_015: X(46, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_015: 0.402s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_MC/user_015/user_015.weights.h5
# → user_016: X(46, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_016: 0.396s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_MC/user_016/user_016.weights.h5
# → user_017: X(46, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_017: 0.403s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_MC/user_017/user_017.weights.h5
# → user_018: X(46, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_018: 0.405s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_MC/user_018/user_018.weights.h5
# → user_019: X(46, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_019: 0.404s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_MC/user_019/user_019.weights.h5
# → user_020: X(46, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_020: 0.411s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_MC/user_020/user_020.weights.h5
# → user_021: X(46, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_021: 0.403s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_MC/user_021/user_021.weights.h5
# → user_022: X(46, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_022: 0.410s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_MC/user_022/user_022.weights.h5
# → user_023: X(46, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_023: 0.409s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_MC/user_023/user_023.weights.h5
# → user_024: X(46, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_024: 0.405s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_MC/user_024/user_024.weights.h5
# → user_025: X(46, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_025: 0.407s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_MC/user_025/user_025.weights.h5
# → user_026: X(46, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_026: 0.407s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_MC/user_026/user_026.weights.h5
# → user_027: X(46, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_027: 0.408s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_MC/user_027/user_027.weights.h5
# → user_028: X(46, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_028: 0.404s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_MC/user_028/user_028.weights.h5
# → user_029: X(46, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_029: 0.429s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_MC/user_029/user_029.weights.h5
# → user_030: X(46, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_030: 0.421s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_MC/user_030/user_030.weights.h5
# → user_031: X(46, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_031: 0.433s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_MC/user_031/user_031.weights.h5
# → user_032: X(46, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_032: 0.404s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_MC/user_032/user_032.weights.h5
# → user_033: X(46, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_033: 0.398s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_MC/user_033/user_033.weights.h5
# → user_034: X(46, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_034: 0.406s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_MC/user_034/user_034.weights.h5
# → user_035: X(46, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_035: 0.415s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_MC/user_035/user_035.weights.h5
# → user_036: X(46, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_036: 0.420s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_MC/user_036/user_036.weights.h5
# → user_037: X(46, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_037: 0.414s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_MC/user_037/user_037.weights.h5
# → user_038: X(46, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_038: 0.403s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_MC/user_038/user_038.weights.h5
# → user_039: X(46, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_039: 0.407s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_MC/user_039/user_039.weights.h5
# → user_040: X(46, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_040: 0.408s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_MC/user_040/user_040.weights.h5
# → user_041: X(46, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_041: 0.405s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_MC/user_041/user_041.weights.h5
# → user_042: X(46, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_042: 0.401s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_MC/user_042/user_042.weights.h5
# → user_043: X(46, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_043: 0.409s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_MC/user_043/user_043.weights.h5
# → user_044: X(46, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_044: 0.407s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_MC/user_044/user_044.weights.h5
# → user_045: X(46, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_045: 0.436s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_MC/user_045/user_045.weights.h5
# → user_046: X(46, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_046: 0.456s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_MC/user_046/user_046.weights.h5
# → user_047: X(46, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_047: 0.415s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_MC/user_047/user_047.weights.h5
# → user_048: X(46, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_048: 0.430s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_MC/user_048/user_048.weights.h5
# → user_049: X(46, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_049: 0.406s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_MC/user_049/user_049.weights.h5
# → user_050: X(46, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_050: 0.443s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_MC/user_050/user_050.weights.h5
# → user_051: X(46, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_051: 0.429s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_MC/user_051/user_051.weights.h5
# → user_052: X(46, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_052: 0.412s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_MC/user_052/user_052.weights.h5
# → user_053: X(46, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_053: 0.425s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_MC/user_053/user_053.weights.h5
# → user_054: X(46, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_054: 0.413s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_MC/user_054/user_054.weights.h5
# → user_055: X(46, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_055: 0.425s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_MC/user_055/user_055.weights.h5
# → user_056: X(46, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_056: 0.455s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_MC/user_056/user_056.weights.h5
# → user_057: X(46, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_057: 0.484s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_MC/user_057/user_057.weights.h5
# → user_058: X(46, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_058: 0.475s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_MC/user_058/user_058.weights.h5
# → user_059: X(46, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_059: 0.505s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_MC/user_059/user_059.weights.h5
# → user_060: X(46, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_060: 0.470s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_MC/user_060/user_060.weights.h5
# → user_061: X(46, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_061: 0.441s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_MC/user_061/user_061.weights.h5
# → user_062: X(46, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_062: 0.423s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_MC/user_062/user_062.weights.h5
# → user_063: X(46, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_063: 0.410s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_MC/user_063/user_063.weights.h5
# → user_064: X(46, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_064: 0.406s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_MC/user_064/user_064.weights.h5
# → user_065: X(46, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_065: 0.408s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_MC/user_065/user_065.weights.h5
# → user_066: X(46, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_066: 0.414s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_MC/user_066/user_066.weights.h5
# → user_067: X(46, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_067: 0.409s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_MC/user_067/user_067.weights.h5
# → user_068: X(46, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_068: 0.392s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_MC/user_068/user_068.weights.h5
# → user_069: X(46, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_069: 0.396s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_MC/user_069/user_069.weights.h5
# → user_070: X(46, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_070: 0.403s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_MC/user_070/user_070.weights.h5
# → user_071: X(46, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_071: 0.422s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_MC/user_071/user_071.weights.h5
# → user_072: X(46, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_072: 0.416s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_MC/user_072/user_072.weights.h5
# → user_073: X(46, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_073: 0.434s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_MC/user_073/user_073.weights.h5
# → user_074: X(46, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_074: 0.446s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_MC/user_074/user_074.weights.h5
# → user_075: X(46, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_075: 0.423s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_MC/user_075/user_075.weights.h5
# → user_076: X(46, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_076: 0.407s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_MC/user_076/user_076.weights.h5
# → user_077: X(46, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_077: 0.442s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_MC/user_077/user_077.weights.h5
# → user_078: X(46, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_078: 0.455s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_MC/user_078/user_078.weights.h5
# → user_079: X(46, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_079: 3.151s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_MC/user_079/user_079.weights.h5
# → user_080: X(46, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_080: 0.422s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_MC/user_080/user_080.weights.h5
# → user_081: X(46, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_081: 0.435s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_MC/user_081/user_081.weights.h5
# → user_082: X(46, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_082: 0.398s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_MC/user_082/user_082.weights.h5
# → user_083: X(46, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_083: 0.433s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_MC/user_083/user_083.weights.h5
# → user_084: X(46, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_084: 0.415s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_MC/user_084/user_084.weights.h5
# → user_085: X(46, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_085: 0.400s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_MC/user_085/user_085.weights.h5
# → user_086: X(46, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_086: 0.407s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_MC/user_086/user_086.weights.h5
# → user_087: X(46, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_087: 0.424s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_MC/user_087/user_087.weights.h5
# → user_088: X(46, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_088: 0.398s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_MC/user_088/user_088.weights.h5
# → user_089: X(46, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_089: 0.412s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_MC/user_089/user_089.weights.h5
# → user_090: X(46, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_090: 0.464s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_MC/user_090/user_090.weights.h5
# → user_091: X(46, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_091: 0.579s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_MC/user_091/user_091.weights.h5
# → user_092: X(46, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_092: 0.463s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_MC/user_092/user_092.weights.h5
# → user_093: X(46, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_093: 0.493s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_MC/user_093/user_093.weights.h5
# → user_094: X(46, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_094: 0.451s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_MC/user_094/user_094.weights.h5
# → user_095: X(46, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_095: 0.451s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_MC/user_095/user_095.weights.h5
# → user_096: X(46, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_096: 0.509s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_MC/user_096/user_096.weights.h5
# → user_097: X(46, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_097: 0.425s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_MC/user_097/user_097.weights.h5
# → user_098: X(46, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_098: 0.400s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_MC/user_098/user_098.weights.h5
# → user_099: X(46, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_099: 0.425s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_MC/user_099/user_099.weights.h5
# → user_100: X(46, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_100: 0.389s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_MC/user_100/user_100.weights.h5
# → user_101: X(46, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_101: 0.392s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_MC/user_101/user_101.weights.h5
# → user_102: X(46, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_102: 0.390s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_MC/user_102/user_102.weights.h5
# → user_103: X(46, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_103: 0.397s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_MC/user_103/user_103.weights.h5
# → user_104: X(46, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_104: 0.391s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_MC/user_104/user_104.weights.h5
# → user_105: X(46, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_105: 0.391s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_MC/user_105/user_105.weights.h5
# → user_106: X(46, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_106: 0.388s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_MC/user_106/user_106.weights.h5
# → user_107: X(46, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_107: 0.397s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_MC/user_107/user_107.weights.h5
# → user_108: X(46, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_108: 0.403s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_MC/user_108/user_108.weights.h5
# → user_109: X(46, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_109: 0.438s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_MC/user_109/user_109.weights.h5
# → user_110: X(46, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_110: 0.421s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_MC/user_110/user_110.weights.h5
# → user_111: X(46, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_111: 0.440s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_MC/user_111/user_111.weights.h5
# → user_112: X(46, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_112: 0.394s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_MC/user_112/user_112.weights.h5
# → user_113: X(46, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_113: 0.391s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_MC/user_113/user_113.weights.h5
# → user_114: X(46, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_114: 0.413s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_MC/user_114/user_114.weights.h5
# → user_115: X(46, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_115: 0.473s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_MC/user_115/user_115.weights.h5
# → user_116: X(46, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_116: 0.439s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_MC/user_116/user_116.weights.h5
# → user_117: X(46, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_117: 0.440s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_MC/user_117/user_117.weights.h5
# → user_118: X(46, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_118: 0.406s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_MC/user_118/user_118.weights.h5
# → user_119: X(46, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_119: 0.408s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_MC/user_119/user_119.weights.h5
# → user_120: X(46, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_120: 0.403s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_MC/user_120/user_120.weights.h5
# → user_121: X(46, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_121: 0.410s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_MC/user_121/user_121.weights.h5
# → user_122: X(46, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_122: 0.397s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_MC/user_122/user_122.weights.h5
# → user_123: X(46, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_123: 0.405s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_MC/user_123/user_123.weights.h5
# → user_124: X(46, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_124: 0.398s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_MC/user_124/user_124.weights.h5
# → user_125: X(46, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_125: 0.422s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_MC/user_125/user_125.weights.h5
# → user_126: X(46, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_126: 0.415s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_MC/user_126/user_126.weights.h5
# → user_127: X(46, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_127: 0.435s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_MC/user_127/user_127.weights.h5
# → user_128: X(46, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_128: 0.414s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/FNN_MC/user_128/user_128.weights.h5
# 🏃 Training LSTM (MC) users (128) …
# → user_001: X(46, 1, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_001: 0.865s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_MC/user_001/user_001.weights.h5
# → user_002: X(46, 1, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_002: 0.926s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_MC/user_002/user_002.weights.h5
# → user_003: X(46, 1, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_003: 0.885s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_MC/user_003/user_003.weights.h5
# → user_004: X(46, 1, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_004: 0.974s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_MC/user_004/user_004.weights.h5
# → user_005: X(46, 1, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_005: 0.871s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_MC/user_005/user_005.weights.h5
# → user_006: X(46, 1, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_006: 0.869s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_MC/user_006/user_006.weights.h5
# → user_007: X(46, 1, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_007: 0.839s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_MC/user_007/user_007.weights.h5
# → user_008: X(46, 1, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_008: 0.842s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_MC/user_008/user_008.weights.h5
# → user_009: X(46, 1, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_009: 0.848s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_MC/user_009/user_009.weights.h5
# → user_010: X(46, 1, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_010: 0.839s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_MC/user_010/user_010.weights.h5
# → user_011: X(46, 1, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_011: 0.847s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_MC/user_011/user_011.weights.h5
# → user_012: X(46, 1, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_012: 0.843s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_MC/user_012/user_012.weights.h5
# → user_013: X(46, 1, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_013: 0.842s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_MC/user_013/user_013.weights.h5
# → user_014: X(46, 1, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_014: 0.850s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_MC/user_014/user_014.weights.h5
# → user_015: X(46, 1, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_015: 0.834s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_MC/user_015/user_015.weights.h5
# → user_016: X(46, 1, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_016: 0.877s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_MC/user_016/user_016.weights.h5
# → user_017: X(46, 1, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_017: 0.867s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_MC/user_017/user_017.weights.h5
# → user_018: X(46, 1, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_018: 0.842s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_MC/user_018/user_018.weights.h5
# → user_019: X(46, 1, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_019: 0.996s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_MC/user_019/user_019.weights.h5
# → user_020: X(46, 1, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_020: 0.860s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_MC/user_020/user_020.weights.h5
# → user_021: X(46, 1, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_021: 0.859s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_MC/user_021/user_021.weights.h5
# → user_022: X(46, 1, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_022: 0.839s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_MC/user_022/user_022.weights.h5
# → user_023: X(46, 1, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_023: 0.847s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_MC/user_023/user_023.weights.h5
# → user_024: X(46, 1, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_024: 0.874s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_MC/user_024/user_024.weights.h5
# → user_025: X(46, 1, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_025: 0.843s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_MC/user_025/user_025.weights.h5
# → user_026: X(46, 1, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_026: 0.880s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_MC/user_026/user_026.weights.h5
# → user_027: X(46, 1, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_027: 0.913s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_MC/user_027/user_027.weights.h5
# → user_028: X(46, 1, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_028: 0.866s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_MC/user_028/user_028.weights.h5
# → user_029: X(46, 1, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_029: 0.853s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_MC/user_029/user_029.weights.h5
# → user_030: X(46, 1, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_030: 0.852s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_MC/user_030/user_030.weights.h5
# → user_031: X(46, 1, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_031: 0.897s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_MC/user_031/user_031.weights.h5
# → user_032: X(46, 1, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_032: 0.883s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_MC/user_032/user_032.weights.h5
# → user_033: X(46, 1, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_033: 0.896s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_MC/user_033/user_033.weights.h5
# → user_034: X(46, 1, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_034: 0.898s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_MC/user_034/user_034.weights.h5
# → user_035: X(46, 1, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_035: 0.880s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_MC/user_035/user_035.weights.h5
# → user_036: X(46, 1, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_036: 0.929s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_MC/user_036/user_036.weights.h5
# → user_037: X(46, 1, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_037: 0.863s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_MC/user_037/user_037.weights.h5
# → user_038: X(46, 1, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_038: 0.865s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_MC/user_038/user_038.weights.h5
# → user_039: X(46, 1, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_039: 0.853s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_MC/user_039/user_039.weights.h5
# → user_040: X(46, 1, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_040: 4.268s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_MC/user_040/user_040.weights.h5
# → user_041: X(46, 1, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_041: 0.993s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_MC/user_041/user_041.weights.h5
# → user_042: X(46, 1, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_042: 0.909s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_MC/user_042/user_042.weights.h5
# → user_043: X(46, 1, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_043: 0.941s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_MC/user_043/user_043.weights.h5
# → user_044: X(46, 1, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_044: 0.908s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_MC/user_044/user_044.weights.h5
# → user_045: X(46, 1, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_045: 0.887s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_MC/user_045/user_045.weights.h5
# → user_046: X(46, 1, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_046: 0.900s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_MC/user_046/user_046.weights.h5
# → user_047: X(46, 1, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_047: 0.898s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_MC/user_047/user_047.weights.h5
# → user_048: X(46, 1, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_048: 0.933s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_MC/user_048/user_048.weights.h5
# → user_049: X(46, 1, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_049: 1.002s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_MC/user_049/user_049.weights.h5
# → user_050: X(46, 1, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_050: 0.890s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_MC/user_050/user_050.weights.h5
# → user_051: X(46, 1, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_051: 0.869s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_MC/user_051/user_051.weights.h5
# → user_052: X(46, 1, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_052: 0.862s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_MC/user_052/user_052.weights.h5
# → user_053: X(46, 1, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_053: 0.874s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_MC/user_053/user_053.weights.h5
# → user_054: X(46, 1, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_054: 0.865s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_MC/user_054/user_054.weights.h5
# → user_055: X(46, 1, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_055: 0.874s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_MC/user_055/user_055.weights.h5
# → user_056: X(46, 1, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_056: 0.871s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_MC/user_056/user_056.weights.h5
# ...
# → user_069: X(46, 1, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_069: 0.842s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_MC/user_069/user_069.weights.h5
# → user_070: X(46, 1, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_070: 0.850s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_MC/user_070/user_070.weights.h5
# → user_071: X(46, 1, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_071: 0.846s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_MC/user_071/user_071.weights.h5
# → user_072: X(46, 1, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_072: 0.844s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_MC/user_072/user_072.weights.h5
# → user_073: X(46, 1, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_073: 0.848s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_MC/user_073/user_073.weights.h5
# → user_074: X(46, 1, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_074: 0.847s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_MC/user_074/user_074.weights.h5
# → user_075: X(46, 1, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_075: 0.935s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_MC/user_075/user_075.weights.h5
# → user_076: X(46, 1, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_076: 0.845s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_MC/user_076/user_076.weights.h5
# → user_077: X(46, 1, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_077: 0.880s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_MC/user_077/user_077.weights.h5
# → user_078: X(46, 1, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_078: 0.923s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_MC/user_078/user_078.weights.h5
# → user_079: X(46, 1, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_079: 0.960s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_MC/user_079/user_079.weights.h5
# → user_080: X(46, 1, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_080: 0.966s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_MC/user_080/user_080.weights.h5
# → user_081: X(46, 1, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_081: 0.890s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_MC/user_081/user_081.weights.h5
# → user_082: X(46, 1, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_082: 0.875s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_MC/user_082/user_082.weights.h5
# → user_083: X(46, 1, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_083: 0.844s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_MC/user_083/user_083.weights.h5
# → user_084: X(46, 1, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_084: 0.839s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_MC/user_084/user_084.weights.h5
# → user_085: X(46, 1, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_085: 0.859s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_MC/user_085/user_085.weights.h5
# → user_086: X(46, 1, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_086: 0.842s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_MC/user_086/user_086.weights.h5
# → user_087: X(46, 1, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_087: 0.856s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_MC/user_087/user_087.weights.h5
# → user_088: X(46, 1, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_088: 0.880s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_MC/user_088/user_088.weights.h5
# → user_089: X(46, 1, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_089: 0.846s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_MC/user_089/user_089.weights.h5
# → user_090: X(46, 1, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_090: 0.851s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_MC/user_090/user_090.weights.h5
# → user_091: X(46, 1, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_091: 0.850s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_MC/user_091/user_091.weights.h5
# → user_092: X(46, 1, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_092: 0.841s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_MC/user_092/user_092.weights.h5
# → user_093: X(46, 1, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_093: 0.851s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_MC/user_093/user_093.weights.h5
# → user_094: X(46, 1, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_094: 0.840s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_MC/user_094/user_094.weights.h5
# → user_095: X(46, 1, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_095: 0.856s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_MC/user_095/user_095.weights.h5
# → user_096: X(46, 1, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_096: 0.846s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_MC/user_096/user_096.weights.h5
# → user_097: X(46, 1, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_097: 0.871s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_MC/user_097/user_097.weights.h5
# → user_098: X(46, 1, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_098: 0.870s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_MC/user_098/user_098.weights.h5
# → user_099: X(46, 1, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_099: 0.882s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_MC/user_099/user_099.weights.h5
# → user_100: X(46, 1, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_100: 0.853s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_MC/user_100/user_100.weights.h5
# → user_101: X(46, 1, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_101: 0.865s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_MC/user_101/user_101.weights.h5
# → user_102: X(46, 1, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_102: 0.851s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_MC/user_102/user_102.weights.h5
# → user_103: X(46, 1, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_103: 0.846s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_MC/user_103/user_103.weights.h5
# → user_104: X(46, 1, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_104: 0.866s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_MC/user_104/user_104.weights.h5
# → user_105: X(46, 1, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_105: 0.847s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_MC/user_105/user_105.weights.h5
# → user_106: X(46, 1, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_106: 0.880s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_MC/user_106/user_106.weights.h5
# → user_107: X(46, 1, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_107: 0.875s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_MC/user_107/user_107.weights.h5
# → user_108: X(46, 1, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_108: 0.969s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_MC/user_108/user_108.weights.h5
# → user_109: X(46, 1, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_109: 0.937s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_MC/user_109/user_109.weights.h5
# → user_110: X(46, 1, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_110: 0.865s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_MC/user_110/user_110.weights.h5
# → user_111: X(46, 1, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_111: 0.886s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_MC/user_111/user_111.weights.h5
# → user_112: X(46, 1, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_112: 0.855s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_MC/user_112/user_112.weights.h5
# → user_113: X(46, 1, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_113: 0.965s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_MC/user_113/user_113.weights.h5
# → user_114: X(46, 1, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_114: 0.874s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_MC/user_114/user_114.weights.h5
# → user_115: X(46, 1, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_115: 4.846s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_MC/user_115/user_115.weights.h5
# → user_116: X(46, 1, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_116: 0.925s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_MC/user_116/user_116.weights.h5
# → user_117: X(46, 1, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_117: 0.871s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_MC/user_117/user_117.weights.h5
# → user_118: X(46, 1, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_118: 0.916s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_MC/user_118/user_118.weights.h5
# → user_119: X(46, 1, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_119: 0.922s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_MC/user_119/user_119.weights.h5
# → user_120: X(46, 1, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_120: 0.967s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_MC/user_120/user_120.weights.h5
# → user_121: X(46, 1, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_121: 0.948s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_MC/user_121/user_121.weights.h5
# → user_122: X(46, 1, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_122: 0.880s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_MC/user_122/user_122.weights.h5
# → user_123: X(46, 1, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_123: 1.020s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_MC/user_123/user_123.weights.h5
# → user_124: X(46, 1, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_124: 0.909s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_MC/user_124/user_124.weights.h5
# → user_125: X(46, 1, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_125: 0.870s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_MC/user_125/user_125.weights.h5
# → user_126: X(46, 1, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_126: 0.921s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_MC/user_126/user_126.weights.h5
# → user_127: X(46, 1, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_127: 0.870s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_MC/user_127/user_127.weights.h5
# → user_128: X(46, 1, 52), y(46,), outputs=4, from_logits=False, loss=sparse_categorical_crossentropy, metric=['sparse_categorical_accuracy']
# ✅ user_128: 0.877s  -> /Users/sohinikar/FL/M.Tech_Dissertation/Client/client_params/LSTM_MC/user_128/user_128.weights.h5
#
# ⏱️ FNN (MC) training time summary:
#    Users trained: 128
#    Avg: 0.443s   Min: 0.388s   Max: 3.151s
#
# ⏱️ LSTM (MC) training time summary:
#    Users trained: 128
#    Avg: 0.938s   Min: 0.834s   Max: 4.846s
#
# 🎉 Done.
